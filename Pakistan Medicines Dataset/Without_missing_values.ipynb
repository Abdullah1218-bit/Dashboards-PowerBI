# %%
import pandas as pd
import numpy as np
import seaborn as ns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Pakistan Medicines Dataset.csv')

# %%
df
# Out:
#           Drug Name      Manufacturer  ... Prescription Required  Price
# 0           Panadol               GSK  ...                    No   35.0
# 1      Arinac Forte             Abott  ...                   Yes    NaN
# 2            Arinac            Abbott  ...                   Yes   65.0
# 3             OMC-D       Sami Pharma  ...                   Yes  100.0
# 4       Paracetamol           Various  ...                    No   30.0
# ..              ...               ...  ...                   ...    ...
# 92  Voveran Emulgel          Novartis  ...                    No  120.0
# 93  Terbinafine Gel       Sami Pharma  ...                   Yes  110.0
# 94       Aczone Gel  Ali Gohar Pharma  ...                   Yes  190.0
# 95    Aloe Vera Gel         Pure Leaf  ...                    No   60.0
# 96   Candid-B Cream          Glenmark  ...                   Yes  100.0
#
# [97 rows x 10 columns]

# %%
imputer=SimpleImputer(strategy='most_frequent')
df_imputed = pd.DataFrame(
    imputer.fit_transform(df),
    columns=df.columns
)

# %%
df_imputed
# Out:
#           Drug Name      Manufacturer  ... Prescription Required  Price
# 0           Panadol               GSK  ...                    No   35.0
# 1      Arinac Forte             Abott  ...                   Yes  100.0
# 2            Arinac            Abbott  ...                   Yes   65.0
# 3             OMC-D       Sami Pharma  ...                   Yes  100.0
# 4       Paracetamol           Various  ...                    No   30.0
# ..              ...               ...  ...                   ...    ...
# 92  Voveran Emulgel          Novartis  ...                    No  120.0
# 93  Terbinafine Gel       Sami Pharma  ...                   Yes  110.0
# 94       Aczone Gel  Ali Gohar Pharma  ...                   Yes  190.0
# 95    Aloe Vera Gel         Pure Leaf  ...                    No   60.0
# 96   Candid-B Cream          Glenmark  ...                   Yes  100.0
#
# [97 rows x 10 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17584\630195457.py in ?()
# ----> 1 df.pd.DataFrame
#
# c:\Users\PC\anaconda3\envs\Base\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'pd'
